# %%
import requests, os

# %%
pond_eth=os.getenv("POND_API_ETH")
pond_base=os.getenv("POND_API_BASE")

# %%
pond_3 = pond_base.split(":8")[0] + ":8003/api/v1/"
pond_3
# Out:
# 'http://model-v2-api-471546444.us-east-1.elb.amazonaws.com:8003/api/v1/'

# %%
res = requests.get(pond_eth + "predict/0x532f27101965dd16442e59d40670faf5ebb142e4").json()
res
# Out:
# [{'address': '0x236aa50979d5f3de3bd1eeb40e81137f22ab794b',
#   'last_activity': '2024-07-06 18:38:57',
#   'prediction': 1325.4148402333062,
#   'test_mse': 0.0006116245943288904,
#   'test_r2': -3.9381264947499073,
#   'test_corr': 0.27606986614682294,
#   'test_trend_acc': 0.5607675906183369,
#   'test_adjust_corr': 0.2481627065562608,
#   'test_trend_acc_binned_truth': '[{"bins": "[0.0, 0.1)", "count_all": 938, "count_neg": 505, "count_pos": 429, "trend_accuracy_all": 0.5607675906183369, "trend_accuracy_neg": 0.2633663366336634, "trend_accuracy_pos": 0.916083916083916}]',
# ...
